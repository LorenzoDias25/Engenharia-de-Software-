# %%
import matplotlib.pyplot as plt

datas = [6, 7, 8, 9]
Alvorada = [14, 11, 16, 23]
Porto = [127, 100, 123, 133]
Viamão = [19, 18, 10, 12]

plt.figure(figsize=(10, 10)) 
plt.plot(datas, Alvorada, label='Alvorada', marker='o')
plt.plot(datas, Porto, label='Porto Alegre', marker='s')
plt.plot(datas, Viamão, label='Viamão', marker='d')

plt.title('Roubo de veiculos em 2023')
plt.xlabel('Datas')
plt.ylabel('Valores')
plt.grid(True)
plt.legend()

plt.show()

# %%
import pandas as pd
import folium

dados = {
    'nome': ['Alvorada', 'Porto Alegre', 'Viamão'],
    'cidade': ['Alvorada', 'Porto Alegre', 'Viamão']
}

df = pd.DataFrame(dados)

coordenadas = {
    'Alvorada': [-29.999939, -51.070272],
    'Porto Alegre': [-30.0346, -51.2177],
    'Viamão': [-30.102932, -51.025887]
    
}

m = folium.Map(location=[-30.028033, -51.086126], zoom_start=12)


for index, row in df.iterrows():
    folium.Marker(location=coordenadas[row['cidade']], 
                  popup=row['nome']).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a61698425e4ab9608c226808d1925873 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a61698425e4ab9608c226808d1925873&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a61698425e4ab9608c226808d1925873 = L.map(
#                 &quot;map_a61698425e4ab9608c226808d1925873&quot;,
#                 {
#                     center: [-30.028033, -51.086126],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b89ed080d0cd949e4446cbe00eed6ed = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_2b89ed080d0cd949e4446cbe00eed6ed.addTo(map_a61698425e4ab9608c226808d1925873);
#
#             var marker_df5f1c6b130b283b3d74eb3812888ad1 = L.marker(
#                 [-29.999939, -51.070272],
#                 {}
#             ).addTo(map_a61698425e4ab9608c226808d1925873);
#
#
#         var popup_67c0ae34d9a0a57cfbe08097830a0afc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd4a163d7939461870babe5f597d1b7e = $(`&lt;div id=&quot;html_dd4a163d7939461870babe5f597d1b7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alvorada&lt;/div&gt;`)[0];
#                 popup_67c0ae34d9a0a57cfbe08097830a0afc.setContent(html_dd4a163d7939461870babe5f597d1b7e);
#
#
#
#         marker_df5f1c6b130b283b3d74eb3812888ad1.bindPopup(popup_67c0ae34d9a0a57cfbe08097830a0afc)
#         ;
#
#
#
#
#             var marker_638a12113371b11ad7a5ae298973ee0b = L.marker(
#                 [-30.0346, -51.2177],
#                 {}
#             ).addTo(map_a61698425e4ab9608c226808d1925873);
#
#
#         var popup_0fb9ca1669db925f54713dab9eeb12c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c22602e462aff397cd8d2eed8516e07 = $(`&lt;div id=&quot;html_9c22602e462aff397cd8d2eed8516e07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Porto Alegre&lt;/div&gt;`)[0];
#                 popup_0fb9ca1669db925f54713dab9eeb12c1.setContent(html_9c22602e462aff397cd8d2eed8516e07);
#
#
#
#         marker_638a12113371b11ad7a5ae298973ee0b.bindPopup(popup_0fb9ca1669db925f54713dab9eeb12c1)
#         ;
#
#
#
#
#             var marker_804aa13a8bbeeafdb9aea9dc071791ea = L.marker(
#                 [-30.102932, -51.025887],
#                 {}
#             ).addTo(map_a61698425e4ab9608c226808d1925873);
#
#
#         var popup_2feb313f6dd1be676126955be3d9733b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2575e2eeb93b2ce3543852887e427794 = $(`&lt;div id=&quot;html_2575e2eeb93b2ce3543852887e427794&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Viamão&lt;/div&gt;`)[0];
#                 popup_2feb313f6dd1be676126955be3d9733b.setContent(html_2575e2eeb93b2ce3543852887e427794);
#
#
#
#         marker_804aa13a8bbeeafdb9aea9dc071791ea.bindPopup(popup_2feb313f6dd1be676126955be3d9733b)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
